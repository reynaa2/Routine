# %%
import numpy as np
import apogee.tools.read as apread
from matplotlib import pyplot as plt
import pylab as pl
import csv

# %%
locationIDs = np.loadtxt('/Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/master_apStarList_DR13.lis',dtype = int, skiprows=1, usecols=[4])
apogeeIDs = np.loadtxt('/Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/master_apStarList_DR13.lis',dtype = str, skiprows=1, usecols=[3])
apogeeIDs = [s.strip('b') for s in apogeeIDs]

# %%
path = np.loadtxt('/Volumes/coveydata-1/APOGEE_Spectra/APOGEE2_DR13/master_apStarList_DR13.lis',dtype = str, skiprows=1, usecols=[5])
path = [k.strip('b') for k in path]

# %%
apoID = []
zero = []
one = []
with open('smallRound_2Binary_Results_EVP1-10_t2','r') as filename2:
    reader2 = csv.reader(filename2, delimiter=',')
    next(reader2,None)
    for rows in reader2:
        #print(rows[0])
        g = (rows[0])
        h = rows[1]
        i = rows[2]
        apoID.append(g)
        zero.append(h)
        one.append(i)

# %%
dr13apoID = []
dr13locID = []
for i in range(len(locationIDs)):
    if len(path[i]) != 36:
        dr13apoID.append(apogeeIDs[i])
        dr13locID.append(locationIDs[i])

# %%
def compare(list1,list2):
    ln= []
    for i in list1:
        if i  in list2:
            ln.append(i)     
    return ln

# %%
compare(dr13apoID,apoID)
# Out:
# []

# %%
print(list(set(apoID)&set(dr13apoID)))
# Out:
# []

# %%
indx = [list(filter(lambda x: x in apoID, sublist)) for sublist in dr13apoID]

# %%
print(indx)
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [
# ...

# %%
set.intersection(set(dr13apoID),set(apoID))
# Out:
# set()

# %%
KM_apoID = np.array(apoID)
print(apogID)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2bd842552211> in <module>()
#       1 KM_apoID = np.array(apoID)
# ----> 2 print(apogID)
#
# NameError: name 'apogID' is not defined

# %%
print(len(locID))

# %%
#apoID = np.array(apoID)
#locID = np.array(locID)

# %%
KMAP = set(KM_apoID)

# %%
LOC = []
for j in range(len(KM_apoID)):
    if KM_apoID[j] in apoID:
        LOC.append(locID[j])

# %%
index = [list(filter(lambda KM_apoID: KM_apoID in apoID,sublist)) for sublist in apoID]

# %%
print(index)
